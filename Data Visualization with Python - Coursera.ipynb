# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('D:/Trainings/Coursera/Data Visualization with Python/rain.json')

# %%
plt.figure(figsize=(15,2))
plt.plot(df['Month'],df['Temperature'],label='Temperature')
plt.show()

# %%
plt.figure(figsize=(17,4))
plt.plot(df['Month'],df['Rainfall'],label='Rainfall')
plt.show()

# %%
plt.figure(figsize=(17,4))
plt.plot(df['Month'],df['Temperature'],label='Temperature')
plt.plot(df['Month'],df['Rainfall'],label='Rainfall')
plt.show()

# %%
df2=pd.read_csv('D:/Trainings/Coursera/Data Visualization with Python/tempYearly.csv')

# %%
sns.scatterplot(x='Year',y='Temperature',data=df2)
plt.show()

# %%
df2=pd.read_csv('D:/Trainings/Coursera/Data Visualization with Python/tempYearly.csv')
sns.set(rc={'figure.figsize':(12,6)})
sns.scatterplot(x='Year',y='Temperature',data=df2)
plt.show()

# %%
df2=pd.read_csv('D:/Trainings/Coursera/Data Visualization with Python/tempYearly.csv')
sns.set(rc={'figure.figsize':(12,6)})
sns.regplot(x='Year',y='Temperature',data=df2)
plt.show()

# %%
df3=pd.read_csv('D:/Trainings/Coursera/Data Visualization with Python/birthYearly.csv')

# %%
df3P = df3.pivot("month","year","births")
print(df3P)
# Out:
# year       2000  2001  2002  2003  2004  2005  2006
# month
# April       229    75   289   214   261   115   299
# August      238   162    86    97   202   158   243
# December    152   286   175   142    58   269   134
# February    168    64   152    71   285   242   201
# January     101   291   274    70    84   279   299
# July        142   285   125   194    77   235   193
# June        183   112   257   103   199   204   136
# March       271   289   248    54    70   258   196
# May         287   141   112   258   175   125    70
# November    108    69   131   152    99   230   175
# October     263   148   274   235   157   224    62
# September   264    96   123   104    53   225   174

# %%
df3
# Out:
#         month  year  births
# 0     January  2000     101
# 1    February  2000     168
# 2       March  2000     271
# 3       April  2000     229
# 4         May  2000     287
# 5        June  2000     183
# 6        July  2000     142
# 7      August  2000     238
# 8   September  2000     264
# 9     October  2000     263
# 10   November  2000     108
# 11   December  2000     152
# 12    January  2001     291
# 13   February  2001      64
# 14      March  2001     289
# 15      April  2001      75
# 16        May  2001     141
# 17       June  2001     112
# 18       July  2001     285
# 19     August  2001     162
# 20  September  2001      96
# 21    October  2001     148
# 22   November  2001      69
# 23   December  2001     286
# 24    January  2002     274
# 25   February  2002     152
# 26      March  2002     248
# 27      April  2002     289
# 28        May  2002     112
# 29       June  2002     257
# ..        ...   ...     ...
# 54       July  2004      77
# ...

# %%
sns.heatmap(df3P,annot=True,fmt='d')

# %%
sns.jointplot("Rainfall","Temperature",data=df2)
plt.show()

# %%
sns.jointplot("Rainfall","Temperature",data=df2,kind="hex")
plt.show()

# %%
sns.jointplot("Rainfall","Temperature",data=df2,kind="reg")
plt.show()
